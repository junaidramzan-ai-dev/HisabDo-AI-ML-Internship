# %%
"""
Day 1: Python Fundamentals & Environment Setup
AI/ML Internship - HisabDo

Topics Covered:
- Printing Output
- Variables
- Data Types
- User Input
- Arithmetic Operations
"""

print("=" * 50)
print("HisabDo AI/ML Internship - Day 1")
print("Python Fundamentals & Environment Setup")
print("=" * 50)

# Variables
name = "Junaid Ramzan"
internship = "AI/ML Internship"

print(f"Name       : {name}")
print(f"Internship : {internship}")

# Data Types
age = 26
height = 5.8
is_student = True

print("\nData Types")
print(type(age))
print(type(height))
print(type(is_student))

# User Input
num1 = int(input("\nEnter first number: "))
num2 = int(input("Enter second number: "))

print("\nResults")
print("Addition       :", num1 + num2)
print("Subtraction    :", num1 - num2)
print("Multiplication :", num1 * num2)
print("Division       :", num1 / num2)

print("\nDay 1 Task Completed Successfully!")
print("=" * 50)
# Out:
# ...
# HisabDo AI/ML Internship - Day 1
# Python Fundamentals & Environment Setup
# ...
# Name       : Junaid Ramzan
# Internship : AI/ML Internship
#
# Data Types
# <class 'int'>
# <class 'float'>
# <class 'bool'>
#
# Results
# Addition       : 10
# Subtraction    : -2
# Multiplication : 24
# Division       : 0.6666666666666666
#
# Day 1 Task Completed Successfully!
# ...

# %%
import sys

print("Python Version:", sys.version)
# Out:
# Python Version: 3.13.1 (tags/v3.13.1:0671451, Dec  3 2024, 19:06:28) [MSC v.1942 64 bit (AMD64)]

# %%
import numpy as np
import pandas as pd

print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
# Out:
# NumPy Version: 2.5.1
# Pandas Version: 3.0.5
